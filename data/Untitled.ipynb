# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.5 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.5 MB 1.7 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.5 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.5 MB 1.8 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.5 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.5 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/11.5 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 3.7/11.5 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.5 MB 2.0 MB/s eta 0:00:04
# ...

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is BA7D-56F1
#
#  Directory of C:\Users\ravin\OneDrive\Desktop\Machine Learning\Movie_Recommendation\data
#
# 04/12/2025  12:18 PM    <DIR>          .
# 04/12/2025  11:54 AM    <DIR>          ..
# 04/12/2025  12:12 PM    <DIR>          .ipynb_checkpoints
# 04/12/2025  11:52 AM       547,817,483 TMDB.csv
# 04/12/2025  12:18 PM             8,720 Untitled.ipynb
#                2 File(s)    547,826,203 bytes
#                3 Dir(s)  742,256,164,864 bytes free

# %%
import pandas as pd
df = pd.read_csv("TMDB.csv")
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...
